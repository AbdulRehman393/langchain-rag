# %% [markdown]
# ## Tool Formats

# %%
pip install -U langchain langchain-core langchain-community langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (1.2.10)
# Requirement already satisfied: langchain-core in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (1.2.13)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.9-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.8 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langchain) (1.0.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langchain-core) (0.7.3)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langchain-core) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langchain-core) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (4.0.0)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.7 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (1.0.7)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (0.3.6)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langgraph<1.1.0,>=1.0.8->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.8->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (4.12.1)
# Requirement already satisfied: certifi in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.8->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Downloading sqlalchemy-2.0.46-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.3-cp311-cp311-win_amd64.whl.metadata (8.4 kB)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.13.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: numpy>=1.26.2 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from langchain-community) (2.4.2)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.8.0-cp311-cp311-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.7.1-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.4.1-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.22.0-cp311-cp311-win_amd64.whl.metadata (77 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain-community)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.6.3)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community)
#   Downloading greenlet-3.3.1-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting openai<3.0.0,>=1.109.1 (from langchain-openai)
#   Downloading openai-2.21.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Collecting distro<2,>=1.7.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Downloading jiter-0.13.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting sniffio (from openai<3.0.0,>=1.109.1->langchain-openai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>4 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.1.15)
# Requirement already satisfied: colorama in C:\Users\rehman.saeed\AppData\Roaming\Python\Python311\site-packages (from tqdm>4->openai<3.0.0,>=1.109.1->langchain-openai) (0.4.6)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.5 MB 1.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.0/2.5 MB 1.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.5 MB 1.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.8/2.5 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 2.4/2.5 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 1.8 MB/s  0:00:01
# Downloading aiohttp-3.13.3-cp311-cp311-win_amd64.whl (457 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ------------------------------ --------- 0.8/1.0 MB 3.7 MB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB 3.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.1 MB/s  0:00:00
# Downloading langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp311-cp311-win_amd64.whl (45 kB)
# Downloading pydantic_settings-2.13.0-py3-none-any.whl (58 kB)
# Downloading sqlalchemy-2.0.46-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB ? eta -:--:--
#    ------------------------ --------------- 1.3/2.1 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 2.2 MB/s  0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.22.0-cp311-cp311-win_amd64.whl (86 kB)
# Downloading langchain_openai-1.1.9-py3-none-any.whl (85 kB)
# Downloading openai-2.21.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    -------------------------------------- - 1.0/1.1 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 2.6 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.13.0-cp311-cp311-win_amd64.whl (204 kB)
# Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.4 kB ? eta -:--:--
#    ----------------------------------- ---- 786.4/879.4 kB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 879.4/879.4 kB 3.0 MB/s  0:00:00
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-win_amd64.whl (44 kB)
# Downloading greenlet-3.3.1-cp311-cp311-win_amd64.whl (226 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading propcache-0.4.1-cp311-cp311-win_amd64.whl (41 kB)
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: sniffio, python-dotenv, propcache, mypy-extensions, multidict, marshmallow, jiter, httpx-sse, greenlet, frozenlist, distro, aiohappyeyeballs, yarl, typing-inspect, tiktoken, SQLAlchemy, aiosignal, pydantic-settings, openai, dataclasses-json, aiohttp, langchain-text-splitters, langchain-openai, langchain-classic, langchain-community
#
#    - --------------------------------------  1/25 [python-dotenv]
#    ------ ---------------------------------  4/25 [multidict]
#    -------- -------------------------------  5/25 [marshmallow]
#    ----------- ----------------------------  7/25 [httpx-sse]
#    ------------ ---------------------------  8/25 [greenlet]
#    ------------ ---------------------------  8/25 [greenlet]
#    ------------ ---------------------------  8/25 [greenlet]
#    ----------------- ---------------------- 11/25 [aiohappyeyeballs]
#    ------------------- -------------------- 12/25 [yarl]
#    ---------------------- ----------------- 14/25 [tiktoken]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    ------------------------ --------------- 15/25 [SQLAlchemy]
#    --------------------------- ------------ 17/25 [pydantic-settings]
#    --------------------------- ------------ 17/25 [pydantic-settings]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ---------------------------- ----------- 18/25 [openai]
#    ------------------------------ --------- 19/25 [dataclasses-json]
#    -------------------------------- ------- 20/25 [aiohttp]
#    -------------------------------- ------- 20/25 [aiohttp]
#    -------------------------------- ------- 20/25 [aiohttp]
#    -------------------------------- ------- 20/25 [aiohttp]
#    --------------------------------- ------ 21/25 [langchain-text-splitters]
#    ----------------------------------- ---- 22/25 [langchain-openai]
#    ----------------------------------- ---- 22/25 [langchain-openai]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    ------------------------------------ --- 23/25 [langchain-classic]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    -------------------------------------- - 24/25 [langchain-community]
#    ---------------------------------------- 25/25 [langchain-community]
#
# Successfully installed SQLAlchemy-2.0.46 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 dataclasses-json-0.6.7 distro-1.9.0 frozenlist-1.8.0 greenlet-3.3.1 httpx-sse-0.4.3 jiter-0.13.0 langchain-classic-1.0.1 langchain-community-0.4.1 langchain-openai-1.1.9 langchain-text-splitters-1.1.0 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 openai-2.21.0 propcache-0.4.1 pydantic-settings-2.13.0 python-dotenv-1.2.1 sniffio-1.3.1 tiktoken-0.12.0 typing-inspect-0.9.0 yarl-1.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.agent_toolkits.load_tools import load_tools

tools = load_tools(["llm-math"],llm=llm)
print(tools[0].name)

print(tools[0].description)

print(tools[0].return_direct)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 from langchain_community.agent_toolkits.load_tools import load_tools
# ----> 3 tools = load_tools(["llm-math"],llm=llm)
#       4 print(tools[0].name)
#       6 print(tools[0].description)
#
# NameError: name 'llm' is not defined

# %% [markdown]
# ## From function to tools

# %%
from langchain_core.tools import tool

@tool
def financial_report(company_name: str, revenue: int, expenses: int)-> str:
    """Generate a financial report for a company that calculates net income."""

net_income = revenue - expenses

report = f"Financial Report for {company_name}: \n"
report += f"Revenue: ${revenue}\n"
report += f"Expenses: ${expenses}\n"
report += f"Net Income: {net_income}\n"
return report
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 7
#       3 @tool
#       4 def financial_report(company_name: str, revenue: int, expenses: int)-> str:
#       5     """Generate a financial report for a company that calculates net income."""
# ----> 7 net_income = revenue_expenses
#       9 report = f"Financial Report for {company_name}: \n"
#      10 report += f"Revenue: ${revenue}\n"
#
# NameError: name 'revenue_expenses' is not defined

# %% [markdown]
# ## Accessing various attributes of a tool

# %%
print(financial_report.name)
print(financial_report.description)
print(financial_report.return_direct)
print(financial_report.args)

# %% [markdown]
# ## Integrating the custom tool

# %%
from langchain.prebuilt import create_react_agent

llm = ChatOpenAI(model = "gpt-4o-mini", api_key = openai_api_key, temperature = 0)
agent = create_react_agent(llm,[financial report])

messages = agent.invoke({"messages":
                         ["human", "TechStack generated made $10 million with $8 million of costs. Generate a financial report."
                         ]
            print(messages)
                         })

# %% [markdown]
# # Tool outputs

# %%
print(messages['messages'[-1].content])

# %% [markdown]
# ## Example

# %% [markdown]
# ## Defining a function for tool use

# %%
# Define a function to retrieve customer info by-name
def retrieve_customer_info(name: str) -> str:
    """Retrieve customer information based on their name."""
    # Filter customers for the customer's name
    customer_info = customers[customers['name'] == name]
    return customer_info.to_string()
  
# Call the function on Peak Performance Co.
print(retrieve_customer_info("Peak Performance Co."))

# %% [markdown]
# ## Defining a function for tool use

# %%
# Convert the retrieve_customer_info function into a tool
@tool
def retrieve_customer_info(name: str) -> str:
    """Retrieve customer information based on their name."""
    customer_info = customers[customers['name'] == name]
    return customer_info.to_string()
  
# Print the tool's arguments
print(retrieve_customer_info.args)

# %% [markdown]
# ## Integrating custom tools with agents

# %%
@tool
def retrieve_customer_info(name: str) -> str:
    """Retrieve customer information based on their name."""
    customer_info = customers[customers['name'] == name]
    return customer_info.to_string()

# Create a ReAct agent
agent = create_react_agent(llm, [retrieve_customer_info])

# Invoke the agent on the input
messages = agent.invoke({"messages": [("human", "Create a summary of our customer: Peak Performance Co.")]})
print(messages['messages'][-1].content)
